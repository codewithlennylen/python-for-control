# %% [markdown]
# ## Plotting Trignonometric Functions

# %%
import math
import matplotlib.pyplot as plt

xdata = []
ydata = []

for x in range (0, 25):
    xdata.append(x)
    y = math.sin(x)
    ydata.append(y)

plt.plot(xdata, ydata)
plt.show()
