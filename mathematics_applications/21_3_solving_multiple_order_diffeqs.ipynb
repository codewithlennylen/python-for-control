# %% [markdown]
# ## Solving Multiple 1st Order Differential Equations
#
# In real life, we typically have higher order differential equations, or we have a set of 1st order differential equations that describe a given system.
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initialization
tstart = -1
tstop = 1
increment = 0.1

# Initial condition
z0 = [1,1]

t = np.arange(tstart, tstop+1, increment)

# Function that returns dx/dt
def mydiff(z, t):
    dxdt = -z[1]
    dydt = z[0]

    dzdt = [dxdt, dydt]
    return dzdt


# Solve ODE
z = odeint(mydiff, z0, t)
print(z)

x = z[:, 0]
y = z[:, 1]

# Plot the results
plt.plot(t, x)
plt.plot(t, y)
plt.xlabel("t")
plt.ylabel("z(t)")
plt.grid()
# plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# [[ 1.          1.        ]
#  [ 0.89517073  1.0948376 ]
#  [ 0.78139722  1.17873591]
#  [ 0.65981623  1.25085671]
#  [ 0.53164262  1.31047933]
#  [ 0.39815699  1.35700808]
#  [ 0.26069311  1.38997806]
#  [ 0.12062447  1.40905984]
#  [-0.02064941  1.41406275]
#  [-0.16171696  1.40493684]
#  [-0.30116869  1.38177326]
#  [-0.43761124  1.34480345]
#  [-0.56968133  1.29439681]
#  [-0.69605934  1.23105698]
#  [-0.81548257  1.15541684]
#  [-0.92675776  1.06823216]
#  [-1.0287731   0.97037406]
#  [-1.12050927  0.8628203 ]
#  [-1.20104969  0.74664553]
#  [-1.26958961  0.62301052]
#  [-1.32544422  0.49315059]
#  [-1.36805543  0.35836327]
#  [-1.39699748  0.21999531]
#  [-1.41198119  0.07942923]
#  [-1.41285686 -0.0619305 ]
#  [-1.39961573 -0.20267144]
#  [-1.3723901  -0.34138735]
#  [-1.33145201 -0.47669223]
#  [-1.27721048 -0.60723416]
#  [-1.21020749 -0.7317088 ]]

# %% [markdown]
# ## Solving Higher Order Differential Equations
#
# ![image.png](attachment:image.png)
#
# Higher order differential equations must be reformulated into a system of first order differential equations
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initialization
tstart = 0
tstop = 5
increment = 0.1

# Initial Condition
x_int = [0,1]

t = np.arange(tstart, tstop+1, increment)

# Function that returns dx/dt
def mydiff(x,t):
    dx1dt = x[1]
    dx2dt = (2 - 2*t*x[1] - 3*x[0])/(1+t**2)

    dxdt = [dx1dt, dx2dt]
    return dxdt

# Solve ODE
x = odeint(mydiff, x_int, t)
# print(x)

x1=x[:,0]
x2=x[:,1]


# Plot the Results
plt.plot(t, x1)
plt.plot(t, x2)
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()
plt.axis((0,5,-1,2))
plt.show()
