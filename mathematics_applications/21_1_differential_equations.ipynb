# %% [markdown]
# ## Differential Equations
#
#
# A differential equation is an equation that relates some function with its derivatives
#
# In applications, the functions usually represent physical quantities, the derivatives represent their rates of change, and the differential equation represents the relationship between the two.
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# Parameters
T = 5
a = -1/T

t = 0
x0 = 1
increment = 1

tstart = 0
tstop = 25


# Simpler alternative
t = np.linspace(tstart, tstop, tstop)
x = np.exp(a*t) * x0

"""
What is the difference between numpy.linspace and numpy.arange?
"""

# x = []
# x = np.zeros(tstop+1)


# t = np.arange(tstart, tstop+1, increment)

# # Define the Equation
# for k in range(tstop):
#     x[k] = math.exp(a*t[k]) * x0


plt.plot(t, x)
plt.xlabel("t")
plt.ylabel("x(t)")
plt.grid()
# plt.axis([0, 25, 0, 1])
plt.show()

# %% [markdown]
# Solving ODEs like this works fine but we must first manually find the solution by pen and paper.
#
# 1. A better alternative is to use ODE solvers in Python.
# 2. Another approach is to solve these equations from "scratch" by making a discrete version of the differential equation, using discretization methods such as Euler, etc

# %% [markdown]
# ### ODE Solvers in Python
#
# The **scipy.integrate** library has 2 powerful functions **ode()** and **odeint()**, for numerically solving first order differential equations (ODEs)
# * The **ode()** is more flexible while **odeint()** (ODE integrator) has a simpler Python interface that works well for most problems.
#
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
from scipy.
